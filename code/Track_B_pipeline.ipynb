# %% [markdown]
# Mount Google Drive to gaine access

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Clone Github Repo

# %%
# !git clone https://github.com/Ericwentz5/airplai-track-a.git
# %cd airplai-track-a
# Out:
# fatal: destination path 'airplai-track-a' already exists and is not an empty directory.
# /content/airplai-track-a

# %% [markdown]
# Set Dependencies

# %%
# !pip install -q supervision==0.27.0 inference roboflow python-dotenv opencv-python numpy tqdm pycuda onnxruntime-gpu==1.19.2
# Out:
# WARNING: python-doctr 1.0.1 does not provide the extra 'torch'

# %% [markdown]
# Set Environment

# %%
from google.colab import userdata
import os
os.environ['ROBOFLOW_API_KEY'] = userdata.get('ROBOFLOW_API_KEY')

# %% [markdown]
# Debug (must have CUDAExecutionProvider in list)

# %%
import onnxruntime as ort
print(ort.get_available_providers())
# Out:
# ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']

# %% [markdown]
# Run Pipeline

# %%
VIDEO_PATH = '/content/drive/MyDrive/AirPlai/test_mac_1.mov'
# !python code/run_pipeline.py --video "{VIDEO_PATH}" --output results/
# Out:
# ...
# ModelDependencyMissing: Your `inference` configuration does not support SAM3 model. Install SAM3 dependencies and set CORE_MODEL_SAM3_ENABLED to True.
# [transformers] `DepthProImageProcessorFast` is deprecated. The `Fast` suffix for image processors has been removed; use `DepthProImageProcessor` instead.
# ...
# ModelDependencyMissing: Your `inference` configuration does not support YoloWorld model. Use pip install 'inference[yolo-world]' to install missing requirements.To suppress this warning, set CORE_MODEL_YOLO_WORLD_ENABLED to False.
# Processing:  47% 457/969 [01:04<01:12,  7.05it/s]
# Exception ignored in: <generator object tqdm.__iter__ at 0x7aef55855b40>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1196, in __iter__
#     self.close()
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1303, in close
#     fp_write('\n')
# ...

# %% [markdown]
# Download result

# %%
# !cp -r results/ '/content/drive/MyDrive/AirPlai/results/'
